# %% [markdown]
# <h1>PDIoT Week 2</h1>
# <p>The plan for this week is to describe the different sensor types and look at some of the walking data that has been collected so far.</p>
# <h2>Sensor types</h2>
# <h3>Accelerometer</h3>
# <ul>
#     <li>Measures acceleration (including gravity)</li>
#     <li>Observing the change in direction of gravity often more useful than linear acceleration due to movement</li>
#     <li>Sensor values given in g along the axis of interest</li>
#     <li>Placing our sensor flat on the table should give -1g on the Z axis and 0g on the other axes</li>
#     <li>Cheap to buy and low power consumption</li>
# </ul>
# <h3>Gyroscope</h3>
# <ul>
#     <li>Directly measures rotational rate</li>
#     <li>Unaffected by gravity direction or linear accelerations</li>
#     <li>Sensor noise will cause drift if used to track orientation</li>
#     <li>Sensor values given in degrees per second about the axis of interest</li>
#     <li>Expensive to buy and much higher power consumption than accelerometer</li>
# </ul>
# <h2>Data Analysis</h2>
# <p>Your are expected to research and develop the step counting algorithm yourselves during the course. A useful first step  will be to look at the walking data visually to understand how the sensors react to different types of walking when mounted in different positions.</p>
#
# <p>You are free to use any programming language for the data analysis part of the project. Below is a simple example using Python/Pandas to graph acceleration and gyroscope data from PDIoT walking data.
#
# <h3>Requirements</h3>
# <ul>
#     <li>Python installation with Jupyter notebook, Pandas and Matplotlib (Anaconda recommended)</li>
# </ul>

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
filename = "../pdiot2018-data/Group B - Nora Walking,100.csv"
#filename = "../pdiot2018-data/Group C - Joao Walking, 100, Wrist Left.csv"
#filename = "../pdiot2018-data/Group G - Emmanuel Ascending, 100.csv"

with open(filename) as f:
    head = [next(f).rstrip().split('# ')[1] for x in xrange(10)]
    for l in head:
        print l
# Out:
# PDIoT walking data"
# Start time: 20180921T123824"
# Group: B"
# Subject:  Walking for 100 steps"
# Activity type: Walking (level ground)"
# Sensor position: Upper Leg"
# Side of body: Right"
# Sensor mounting: Body"
# Number of steps: 100"
# Notes: "

# %%
    
df = pd.read_csv(filename, header=11)
print(df)
# Out:
#           timestamp   seq   accel_x   accel_y   accel_z     gyro_x    gyro_y  \
# 0     1537529904944     0 -0.950195  0.202148 -0.265625    0.12500  -0.15625
# 1     1537529904952     1 -0.952148  0.200195 -0.261719    0.12500   0.09375
# 2     1537529904952     2 -0.952148  0.203125 -0.259766   -0.31250  -0.28125
# 3     1537529904952     3 -0.953125  0.204102 -0.260742   -0.43750  -0.65625
# 4     1537529904952     4 -0.949219  0.199219 -0.262695   -0.96875  -0.65625
# 5     1537529905141     5 -0.951172  0.209961 -0.261719   -1.40625  -0.81250
# 6     1537529905141     6 -0.950195  0.208008 -0.266602   -2.31250  -1.06250
# 7     1537529905142     7 -0.950195  0.203125 -0.265625   -1.71875  -0.87500
# 8     1537529905142     8 -0.950195  0.198242 -0.267578   -1.09375  -0.68750
# 9     1537529905143     9 -0.952148  0.200195 -0.260742   -1.53125  -0.68750
# 10    1537529905340    10 -0.951172  0.207031 -0.267578   -1.03125  -0.40625
# ...

# %%
df.plot(y=['accel_x', 'accel_y', 'accel_z'])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
df.plot(y=['gyro_x', 'gyro_y', 'gyro_z'])
# Out:
# <img src="data:image/png;base64,..." width="640">
